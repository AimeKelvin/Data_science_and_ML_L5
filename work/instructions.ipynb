# %% [markdown]
# # 1. Assignment Background
# In real-world data science projects, data is rarely clean or perfectly structured. Analysts frequently deal with different errors that can be made during data collection
#
# This assignment simulates an institutional dataset and requires student to load, analyze, clean, and interpret data

# %% [markdown]
# # 2. Task Breakdown
# ## Task 1: Data Understanding & Planning (10% marks)
# - Study the dataset structure
# - Identify expected data types<br>
# **Deliverable:**
# Using Jupyter Notebook Documentation style to:
# - identify the expected data type
# - identify type of errors that can be made during data correction
# - identify steps you are going to follow for identify and correct erroros

# %% [markdown]
# ## Task 2: Loading Data Using pandas (20%)
# Use pandas to load the CSV file.<br>
# **Deliverable:**
# - Code snippet
# - Add explanation of each function used

# %% [markdown]
# ## Task 3: Explorating dataset issues (30% marks)
# - Study the dataset and explorate all errors in it<br>
# **Deliverable:**
# - Code snippet
# - Using Jupyter Notebook Documentation style to:
#   - List the errors found in dataset and possible way to solve each error
#   - Add explanation of each function used

# %% [markdown]
# ## Task 4: Data preparation (40% marks)
# - correct all errors found in task 4 in dataset<br>
# **Deliverable:**
# - Code snippet
# - Using Jupyter Notebook Documentation style to:
#   - Add explanation of each function used
